# %%
# !pip install pandas
# or pip install pandas in cmd
# Out:
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 428.4 kB/s eta 0:00:22
#    -- ------------------------------------- 0.5/9.9 MB 428.4 kB/s eta 0:00:22
#    -- ------------------------------------- 0.5/9.9 MB 428.4 kB/s eta 0:00:22
#    --- ------------------------------------ 0.8/9.9 MB 463.7 kB/s eta 0:00:20
#    --- ------------------------------------ 0.8/9.9 MB 463.7 kB/s eta 0:00:20
#    ---- ----------------------------------- 1.0/9.9 MB 460.9 kB/s eta 0:00:20
#    ---- ----------------------------------- 1.0/9.9 MB 460.9 kB/s eta 0:00:20
# ...

# %%
import pandas as pd

# %%
ecom = pd.read_csv('ecommerce_purchase.csv')

# %%
ecom.head()
# Out:
#    OrderID CustomerID   CustomerName                 Email            Product  \
# 0     1001       C001     John Smith  john.smith@email.com     Wireless Mouse
# 1     1002       C002  Sarah Johnson     sarah.j@email.com      Running Shoes
# 2     1003       C003  Michael Brown   michael.b@email.com  Bluetooth Speaker
# 3     1004       C004    Emily Davis     emily.d@email.com       Coffee Maker
# 4     1005       C005   David Wilson     david.w@email.com         Desk Chair
#
#           Category  Quantity   Price PaymentMethod PurchaseDate    Country
# 0      Electronics         2   25.99   Credit Card   2024-01-05        USA
# 1          Fashion         1   79.99        PayPal   2024-01-06     Canada
# 2      Electronics         1   49.99    Debit Card   2024-01-07         UK
# 3  Home Appliances         1   89.99   Credit Card   2024-01-08  Australia
# 4        Furniture         1  129.99   Net Banking   2024-01-09        USA

# %%
ecom.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   OrderID        15 non-null     int64
#  1   CustomerID     15 non-null     str
#  2   CustomerName   15 non-null     str
#  3   Email          15 non-null     str
#  4   Product        15 non-null     str
#  5   Category       15 non-null     str
#  6   Quantity       15 non-null     int64
#  7   Price          15 non-null     float64
#  8   PaymentMethod  15 non-null     str
#  9   PurchaseDate   15 non-null     str
#  10  Country        15 non-null     str
# dtypes: float64(1), int64(2), str(8)
# memory usage: 1.4 KB

# %%
ecom.head(2)
# Out:
#    OrderID CustomerID   CustomerName                 Email         Product  \
# 0     1001       C001     John Smith  john.smith@email.com  Wireless Mouse
# 1     1002       C002  Sarah Johnson     sarah.j@email.com   Running Shoes
#
#       Category  Quantity  Price PaymentMethod PurchaseDate Country
# 0  Electronics         2  25.99   Credit Card   2024-01-05     USA
# 1      Fashion         1  79.99        PayPal   2024-01-06  Canada

# %%
ecom['Price'].mean()
#mean() used for show average values
# Out:
# np.float64(212.72333333333324)

# %%
ecom['Price'].max()
# Out:
# np.float64(999.99)

# %%
ecom['Price'].min()
# Out:
# np.float64(4.99)

# %%
ecom[ecom['Category']=='Fashion'].count()
#sal['JobTitle'].value_counts().head()
# Out:
# OrderID          2
# CustomerID       2
# CustomerName     2
# Email            2
# Product          2
# Category         2
# Quantity         2
# Price            2
# PaymentMethod    2
# PurchaseDate     2
# Country          2
# dtype: int64

# %%
ecom.head(1)
# Out:
#    OrderID CustomerID CustomerName                 Email         Product  \
# 0     1001       C001   John Smith  john.smith@email.com  Wireless Mouse
#
#       Category  Quantity  Price PaymentMethod PurchaseDate Country
# 0  Electronics         2  25.99   Credit Card   2024-01-05     USA

# %%
ecom[ecom['PaymentMethod'].str.contains("Credit Card")]['PaymentMethod'].count()
# Out:
# np.int64(6)

# %%
ecom['Category'].value_counts().head()
# Out:
# Category
# Electronics        6
# Fashion            2
# Home Appliances    2
# Furniture          2
# Accessories        2
# Name: count, dtype: int64

# %%
ecom['PaymentMethod'].value_counts().head()
# Out:
# PaymentMethod
# Credit Card    6
# PayPal         3
# Debit Card     3
# Net Banking    1
# UPI            1
# Name: count, dtype: int64

# %%
ecom.head(1)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
#
#                                         Browser Info          Company  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...  Martinez-Herman
#
#         Credit Card CC Exp Date  CC Security Code   CC Provider  \
# 0  6011929061123406       02/20               900  JCB 16 digit
#
#                Email                                     Job       IP Address  \
# 0  pdunlap@yahoo.com  Scientist, product/process development  149.146.147.205
#
#   Language  Purchase Price
# 0       el           98.14

# %%
ecom[ecom['Product'] == 'Laptop']['Price']
# ecom[ecom['Country'] == 'USA']['CustomerName']
# Out:
# 8    999.99
# Name: Price, dtype: float64

# %%
ecom[ecom['CustomerID']=='C005']['Email']
# Out:
# 4    david.w@email.com
# Name: Email, dtype: str

# %%
ecom[(ecom['Product']=='Wireless Mouse') & (ecom['Price'] > 5)].count()
# Out:
# OrderID          1
# CustomerID       1
# CustomerName     1
# Email            1
# Product          1
# Category         1
# Quantity         1
# Price            1
# PaymentMethod    1
# PurchaseDate     1
# Country          1
# dtype: int64

# %%
ecom[ecom['Country'].str.contains("USA")]['Country'].count() #Using str.contains to find the /25 year
# Out:
# np.int64(4)

# %%
#ecom['Email Domain'] = ecom['Email'].str.split("@").str[1] #Generate another column with email dominas using str split at the @ element, we keep the domain only
ecom['Email'].str.split("@").str[1]
# Out:
# 0     email.com
# 1     email.com
# 2     email.com
# 3     email.com
# 4     email.com
# 5     email.com
# 6     email.com
# 7     email.com
# 8     email.com
# 9     email.com
# 10    email.com
# 11    email.com
# 12    email.com
# 13    email.com
# 14    email.com
# Name: Email, dtype: object

# %%
ecom.head(1)
# Out:
#    OrderID CustomerID CustomerName                 Email         Product  \
# 0     1001       C001   John Smith  john.smith@email.com  Wireless Mouse
#
#       Category  Quantity  Price PaymentMethod PurchaseDate Country
# 0  Electronics         2  25.99   Credit Card   2024-01-05     USA

# %%
ecom['Email'].value_counts().head()
#ecom['Job'].value_counts().head()
# Out:
# Email
# john.smith@email.com    1
# sarah.j@email.com       1
# michael.b@email.com     1
# emily.d@email.com       1
# david.w@email.com       1
# Name: count, dtype: int64
